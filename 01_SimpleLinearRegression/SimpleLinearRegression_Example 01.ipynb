# %% [markdown]
# # ***Regression***
#
# ---
#
# ***Regression*** is a statistical method used in finance, investing, and other disciplines that attempts to determine the strength and character of the relationship between one dependent variable (usually denoted by Y) and a series of other variables (known as independent variables).
#
# ***Correlation*** is a statistical measure that expresses the extent to which two variables are linearly related (meaning they change together at a constant rate).
#
# ***If there's no correlation then there can't be any Regression ***

# %% [markdown]
# every line on graph has certain equation , if it has equation then there will be correlation

# %% [markdown]
# # ***Simple Linear Regression***
#
# ---
# Consider the model function
#
# ***y = α + βx or y = mx +c***
#
# which describes a line with slope β and y-intercept α. In general such a relationship may not hold exactly for the largely unobserved population of values of the independent and dependent variables; we call the unobserved deviations from the above equation the errors.

# %% [markdown]
# ![hjm,.png](data:image/png;base64,...)

# %% [markdown]
# Here on obvoius fact, y is a dependent variable and x is an independant variable.
# There can be some error; there is no need of standardization but there is a need of preprocessing (the model of linear regression is very fast)

# %% [markdown]
# ***Residual***
#
# ---
#
# residual = actualvalue - estimatedvalue ***bold text***
#
# or
#
# ***e = y - ŷ***
#
# Residual is the difference between actual value and estimated value.

# %% [markdown]
# ![fhdf.png](data:image/png;base64,...)

# %% [markdown]
# # ***Where is Linear Regression Used ?***
#
# ---
# Evaluating Trends and Sales Estimates
# Analyzing the Impact of Price Changes
# Assessment of risk in financial services and insurance domain
#
#
# *   Evaluating Trends and Sales Estimates
# *   Analyzing the Impact of Price Changes
# *   Assessment of risk in financial services and insurance domain

# %% [markdown]
# # ***Simple Linear Regression Algorithm***
#
# ---
# ***Mathematical Intuition![gytujh.png](data:image/png;base64,...)***

# %% [markdown]
# ***Getting Started with Linear Regression***
#
# ---

# %%
# importing libraries

import numpy as np # ML model can only understand numpy arrays even images are converted to numerical values
import pandas as pd 
import matplotlib.pyplot as plt # For visualization
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
import math

# %% [markdown]
# ***Data Framing***
# Reading .csv data into a DataFrame

# %%
dataset = pd.read_csv("headbrain.csv")
dataset.head() #head shows the first five rows of dataset
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
size = dataset['Head Size(cm^3)']
weight = dataset['Brain Weight(grams)']
#importing columns on which regression will be performed from the dataset
print(size)
print(weight)
# Out:
# 0      4512
# 1      3738
# 2      4261
# 3      3777
# 4      4177
#        ...
# 232    3214
# 233    3394
# 234    3233
# 235    3352
# 236    3391
# Name: Head Size(cm^3), Length: 237, dtype: int64
# 0      1530
# 1      1297
# 2      1335
# 3      1282
# 4      1590
#        ...
# 232    1110
# 233    1215
# 234    1104
# 235    1170
# 236    1120
# Name: Brain Weight(grams), Length: 237, dtype: int64

# %% [markdown]
# ***Visualizing Dataset***

# %%
plt.scatter(size, weight)
plt.show()

# %% [markdown]
# ***Converting Data Frames into Numpy Arrays***
#
# ---
#
#
# Machine Learning handle arrays not dataframes

# %%
X = np.array(size).reshape(-1,1)
y = np.array(weight).reshape(-1,1)
#reshaping is done for getting one-dimensional array

# %% [markdown]
# ***Training the model***
#
# ---
#
# We are using Linear regression model as imported from sklearn library and then it's being trained on x and y (any 2 major axis of datasets)

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
#        [1294.99339037],
#        [1231.50691955],
#        [1340.5666661 ],
#        [1156.95641648],
#        [1189.35822524],
#        [1302.10598254],
#        [1380.87135504],
#        [1186.72393184],
#        [1134.56492262],
#        [1321.07289498],
#        [1260.22071756],
#        [1192.78280665],
#        [1246.78582124],
#        [1137.46264536],
#        [1181.19191571],
#        [1210.16914305],
#        [1327.39519913],
#        [1264.96244567],
#        [1154.05869374],
#        [1248.36639728],
#        [1266.27959237],
#        [1306.58428131],
#        [1277.8704833 ],
#        [1169.33759543],
#        [1276.28990727],
#        [1263.64529897],
#        [1373.75876288],
#        [1256.26927747],
#        [1297.36425443],
#        [1157.48327516],
#        [1380.6079257 ],
#        [1163.54214997],
#        [1242.04409313],
#        [1284.98307547],
#        [1282.34878207],
#        [1134.03806394],
#        [1219.65259928],
#        [1301.05226518],
#        [1159.32728053],
#        [1209.1154257 ],
#        [1115.86143952],
#        [1296.83739575],
#        [1262.32815227],
#        [1056.06297945],
#        [1131.14034121],
#        [1206.4811323 ],
#        [1245.73210389],
#        [1194.09995335],
#        [1210.69600173],
#        [1175.92332892],
#        [1188.83136656],
#        [1340.03980742],
#        [1133.51120526],
#        [1298.15454244],
#        [1221.76003399],
#        [1377.97363231],
#        [1199.63196948],
#        [1042.10122446],
#        [1099.26539113],
#        [1268.65045642],
#        [1099.79224981],
#        [1112.96371678],
#        [1270.23103246],
#        [1156.95641648],
#        [1180.66505703],
#        [1160.64442723],
#        [1186.4605025 ],
#        [1218.33545258],
#        [1216.22801786],
#        [1080.03504935],
#        [1310.79915074],
#        [1242.04409313],
#        [1286.30022217],
#        [1304.47684659],
#        [1190.67537193],
#        [1433.03036426],
#        [1309.48200404],
#        [1173.28903553],
#        [1296.31053707],
#        [1301.31569452],
#        [1172.23531817],
#        [1219.65259928],
#        [1177.24047562],
#        [1208.58856702],
#        [1218.86231126]])

# %% [markdown]
# **Model Evaluation**

# %% [markdown]
# ***Mean Sqaured Error & R - Squared Value***
#
# ---
#
# The ***mean squared error or mean squared deviation*** of an estimator measures the average of the squares of the errors—that is, the average squared difference between the estimated values and the actual value. MSE is a risk function, corresponding to the expected value of the squared error loss.
#
# The ***coefficient of determination***, denoted R² or r² and pronounced "R squared", is the proportion of the variance in the dependent variable that is predictable from the independent variable.
#
# ![gyhfgvn.png](data:image/png;base64,...)

# %% [markdown]
# we done squaring so that the difference can be visualized between values

# %%
regression_model_mse = mean_squared_error(X,y)
rmse = math.sqrt(regression_model_mse)
r2 = model.score(X,y)

# %%
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.26342934]]
# Intercept: [325.57342105]
# Root mean squared error:  2367.495611943946
# R2 score:  0.639311719957

# %% [markdown]
# ***Visualization***
#
# ---
# Visualize the dataset with the fit model using matplotlib.

# %%
plt.scatter(X,y, color = 'orange')
plt.plot(X,model.predict(X), color = 'black')
plt.title('Linear Regression')
plt.xlabel('Head Size')
plt.ylabel('Brain Weight')
# Out:
# Text(0, 0.5, 'Brain Weight')

# %% [markdown]
# ***Prediction***
#
# ---
#
# We will predict the Brain weight by giving an input of Brain Size

# %%
print('Prediction by the model:\t', model.predict([[2000]]))
# Out:
# Prediction by the model:	 [[852.43210003]]
